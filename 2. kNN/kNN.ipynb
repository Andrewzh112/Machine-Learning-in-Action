# %%
import kNN

# %%
group, labels = kNN.createDataSet()

# %%
kNN.kNN_classifier0([0,0], group, labels, 3)
# Out:
# 'B'

# %%
datingDataMat, datingLabels = kNN.file2matrix('datingTestSet.txt')

# %%
datingDataMat
# Out:
# array([[4.0920000e+04, 8.3269760e+00, 9.5395200e-01],
#        [1.4488000e+04, 7.1534690e+00, 1.6739040e+00],
#        [2.6052000e+04, 1.4418710e+00, 8.0512400e-01],
#        ...,
#        [2.6575000e+04, 1.0650102e+01, 8.6662700e-01],
#        [4.8111000e+04, 9.1345280e+00, 7.2804500e-01],
#        [4.3757000e+04, 7.8826010e+00, 1.3324460e+00]])

# %%
datingLabels[:20]
# Out:
# ['largeDoses',
#  'smallDoses',
#  'didntLike',
#  'didntLike',
#  'didntLike',
#  'didntLike',
#  'largeDoses',
#  'largeDoses',
#  'didntLike',
#  'largeDoses',
#  'didntLike',
#  'didntLike',
#  'smallDoses',
#  'didntLike',
#  'didntLike',
#  'didntLike',
#  'didntLike',
#  'didntLike',
#  'smallDoses',
#  'largeDoses']

# %%
import matplotlib
import matplotlib.pyplot as plt
colors = list(map(lambda x: 'blue' if x == 'largeDoses' else ('green' if x == 'smallDoses' else 'red'), datingLabels))
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(datingDataMat[:, 0], datingDataMat[:, 1], c=colors)
plt.show()

# %%
normMat, ranges, minVals = kNN.autoNorm(datingDataMat)

# %%
normMat
# Out:
# array([[0.44832535, 0.39805139, 0.56233353],
#        [0.15873259, 0.34195467, 0.98724416],
#        [0.28542943, 0.06892523, 0.47449629],
#        ...,
#        [0.29115949, 0.50910294, 0.51079493],
#        [0.52711097, 0.43665451, 0.4290048 ],
#        [0.47940793, 0.3768091 , 0.78571804]])

# %%
kNN.datingClassTest()
# Out:
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with largeDoses, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is largeDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with largeDoses, the real answer is largeDoses
# the classifier came back with smallDoses, the real answer is smallDoses
# the classifier came back with didntLike, the real answer is didntLike
# the classifier came back with largeDoses, the real answer is didntLike
# the total error rate is: 0.05

# %%
kNN.classifyPerson()
# Out:
# You will probably like this person smallDoses

# %%
testVector = kNN.img2vector('testDigits/0_13.txt')

# %%
testVector
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
kNN.handwritingClassTest()
# Out:
# answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 6, the real answer is 6
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 7, the real answer is 7
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 6, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 3, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 1, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 1, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 8, the real answer is 8
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 1, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 7, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the classififer came back with 9, the real answer is 9
# the total number of errors is 10
# the total eroor rate is 0.010570824524312896
